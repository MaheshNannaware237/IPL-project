# %%
import pandas as pd

df = pd.read_csv("IPL.csv")
df.head()
# Out:
# <ipython-input-7-2389210657>:3: DtypeWarning: Columns (28,29,30,31,43,46,47,48,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("IPL.csv")
#    Unnamed: 0  match_id        date match_type             event_name  \
# 0      131970    335982  2008-04-18        T20  Indian Premier League
# 1      131971    335982  2008-04-18        T20  Indian Premier League
# 2      131972    335982  2008-04-18        T20  Indian Premier League
# 3      131973    335982  2008-04-18        T20  Indian Premier League
# 4      131974    335982  2008-04-18        T20  Indian Premier League
#
#    innings           batting_team                 bowling_team  over  ball  \
# 0        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     1
# 1        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     2
# 2        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     3
# ...

# %%
import pandas as pd

# Load data
df = pd.read_csv("IPL.csv")

# Basic info and stats
print(df.info())
print(df.describe())
print(df['batting_team'].value_counts())  # Example: Count of matches per team
# Out:
# <ipython-input-4-184e0fa084b4>:4: DtypeWarning: Columns (43,46,47,48,51,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("IPL.csv")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145497 entries, 0 to 145496
# Data columns (total 64 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         145497 non-null  int64
#  1   match_id           145497 non-null  int64
#  2   date               145497 non-null  object
#  3   match_type         145497 non-null  object
#  4   event_name         145497 non-null  object
#  5   innings            145497 non-null  int64
#  6   batting_team       145497 non-null  object
#  7   bowling_team       145497 non-null  object
#  8   over               145497 non-null  int64
#  9   ball               145497 non-null  int64
#  10  ball_no            145497 non-null  float64
#  11  batter             145497 non-null  object
# ...

# %%
import numpy as np

# Example: Average and Max runs using numpy
runs = df['runs_total'].values
average_runs = np.mean(runs)
max_runs = np.max(runs)

print("Average Runs:", average_runs)
print("Max Runs:", max_runs)
# Out:
# Average Runs: 1.2900884554320708
# Max Runs: 7

# %%
import matplotlib.pyplot as plt

# Bar chart: Runs by teams
df.groupby('batting_team')['runs_total'].sum() \
  .sort_values(ascending=False) \
  .plot(kind='bar', figsize=(10, 5))

plt.title('Total Runs by Team')
plt.xlabel('Team')
plt.ylabel('Runs')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Total runs scored by each team
team_runs = df.groupby('batting_team')['runs_total'].sum()

# Plot pie chart
plt.figure(figsize=(10, 10))
plt.pie(team_runs, labels=team_runs.index, autopct='%1.1f%%', startangle=140)
plt.title('Percentage of Total Runs by Each Team')
plt.axis('equal')  # Equal aspect ratio makes it a perfect circle
plt.show()
